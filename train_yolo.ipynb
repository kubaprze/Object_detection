# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11m.pt")

results = model.train(data="data/data.yaml", epochs=10, imgsz=640, device=0)
# Out:
# Ultralytics 8.3.107  Python-3.13.2 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from IPython.display import Image

Image("runs/detect/train2/confusion_matrix_normalized.png", height=1000, width=1000)

# %%
Image("runs/detect/train2/results.png",height=1000, width=1000)

# %%
#Predictions
Image("runs/detect/train2/val_batch0_pred.jpg", height=1000, width=1000)
